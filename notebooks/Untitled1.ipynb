# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#align_evaluation_train_align_metric_hard_accuracy_align
plt.plot([0.6641, 0.8438, 0.9411, 0.9753, 0.9575, 0.9180, 0.8236, 0.5709])

# %%
#align_evaluation_train_align_metric_hard_f1_align
plt.plot([0.7485, 0.8649, 0.9442, 0.9716, 0.9750, 0.9558, 0.9106, 0.7858, 0.2484])
